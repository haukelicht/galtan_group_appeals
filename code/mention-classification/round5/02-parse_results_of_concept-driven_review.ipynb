# %%
import os 
import pandas as pd
import numpy as np
from pathlib import Path

data_path = Path('../../../data/annotations/group_mention_categorization')

# %%
fp = data_path / 'consolidated_annotations.tsv'
annotations = pd.read_csv(fp, sep='\t')
ignore = ['stance: ', 'universal: ']
annotations.query("attribute_combination not in @ignore", inplace=True)

# %%
annotations.groupby(['mention_id', 'attribute_combination']).filter(lambda x: x.label.nunique() > 1)
# Out:
#                  mention_id  \
# 2671  41112_199012-127111-2
# 7912  41112_199012-127111-2
#
#                                                    text  \
# 2671  Their clients are men from all walks of life a...
# 7912  Their clients are men from all walks of life a...
#
#                                          mention  \
# 2671  men from all walks of life and professions
# 7912  men from all walks of life and professions
#
#                                              prev_texts  \
# 2671  And it’s usually men who organize and earn: as...
# 7912  And it’s usually men who organize and earn: as...
#
#                                              next_texts  \
# 2671  Any man can be.\nAnd the state also benefits f...
# 7912  Any man can be.\nAnd the state also benefits f...
#
#                          q_id  q_category          category label  round  \
# 2671  non-economic_attributes         3.0  gender/sexuality   Yes      1
# 7912  non-economic_attributes         3.0  gender/sexuality    No      2
#
#          attribute           attribute_combination
# 2671  non-economic  non-economic: gender/sexuality
# 7912  non-economic  non-economic: gender/sexuality

# %%
annotations = annotations[~np.logical_and(annotations['mention_id']=='41112_199012-127111-2', annotations['round']==2)]

# %%
pre_review = annotations[['mention_id', 'attribute_combination', 'label']]

# %% [markdown]
# # Parse expert review annotations

# %%
fp = data_path / 'social-group-mention-categorization-expert-consolidation' / 'reviewed.xlsx'

# list sheets in workbook
sheets = pd.ExcelFile(fp).sheet_names

# %% [markdown]
# ### check for internal inconsistencies

# %%
dfs = []
for i, sheet in enumerate(sheets):
    df = pd.read_excel(fp, sheet_name=sheet)
    attribute_cols = df.columns[df.columns.str.contains(': ')]
    df[attribute_cols] = df[attribute_cols].replace({np.nan: 'No'})
    df = df.melt(id_vars=['mention_id', 'text', 'mention'], value_vars=attribute_cols, var_name='attribute_combination', value_name='label').sort_values(by=['mention_id', 'attribute_combination']).reset_index(drop=True)
    df['sheet'] = i+1
    dfs.append(df)

df = pd.concat(dfs, ignore_index=True)

# %%
# NOTE: should be none !!!
df.sort_values(['mention_id', 'attribute_combination']).groupby(['mention_id', 'attribute_combination']).filter(lambda x: x.label.nunique() > 1)
# Out:
# Empty DataFrame
# Columns: [mention_id, text, mention, attribute_combination, label, sheet]
# Index: []

# %% [markdown]
# ### List edits to be implemented

# %%
def split_and_strip(x):
    if x is np.NaN:
        return set()
    if isinstance(x, list):
        return set([s.strip() for s in x if s.strip() != ''])
    if isinstance(x, str):
        return set([s.strip() for s in x.split(';') if s.strip() != ''])
    return set()

dfs = []
cols = ['mention_id', 'text', 'mention', 'discard codings', 'add codings']
for i, sheet in enumerate(sheets):
    df = pd.read_excel(fp, sheet_name=sheet)
    idxs = np.logical_or(df['discard codings'].notna(), df['add codings'].notna())
    df = df[idxs]
    df['discard codings'] = df['discard codings'].map(split_and_strip)
    df['add codings'] = df['add codings'].map(split_and_strip)
    df = df[cols]
    df['sheet_nr'] = i+1
    dfs.append(df)

# %%
df = pd.concat(dfs, ignore_index=True)
df.sort_values(['mention_id', 'sheet_nr'], inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
# function checking disagreement between sets
from typing import List, Union
def any_inconsistencies(sets: Union[pd.Series, List[set]]) -> bool:
    if isinstance(sets, pd.Series):
        sets = sets.tolist()
    elif not isinstance(sets, list):
        raise TypeError("Input must be a list or a pandas Series of sets.")
    if not sets:
        return False
    union_set = set.union(*sets)
    for s in sets:
        if s != union_set:
            return True
        if s - union_set:
            return True
    return False
print(any_inconsistencies([{1, 2}, {1, 2, 3}]))  # should return True
print(any_inconsistencies([{1, 2}, {3, 4}]))  # should return True
print(any_inconsistencies([{1, 2}, {2, 3}]))  # should return True
print(any_inconsistencies([{1, 2}, {1, 2}]))  # should return False
# Out:
# True
# True
# True
# False

# %%
# check if any inconsistencies in the discard codings for a given mention
these = df.groupby('mention_id')['discard codings'].agg(any_inconsistencies)
these = these[these].index.tolist()
# NOTE: should be none !!!
df[df.mention_id.isin(these)]
# Out:
# Empty DataFrame
# Columns: [mention_id, text, mention, discard codings, add codings, sheet_nr]
# Index: []

# %%
# check if any inconsistencies in the discard codings for a given mention
these = df.groupby('mention_id')['add codings'].agg(any_inconsistencies)
these = these[these].index.tolist()
# NOTE: should be none !!!
df[df.mention_id.isin(these)]
# Out:
# Empty DataFrame
# Columns: [mention_id, text, mention, discard codings, add codings, sheet_nr]
# Index: []

# %%
# mid = '80710_200907-92925-2'
# pre_review[pre_review.mention_id == mid]

# %%
set.union(*df['discard codings'].tolist())
# Out:
# {'age',
#  'class membership',
#  'crime',
#  'ecology of group',
#  'education level',
#  'employment status',
#  'ethnicity',
#  'family',
#  'gender/sexuality',
#  'health',
#  'income/wealth/economic status',
#  'nationality',
#  'occupation/profession',
#  'shared values/mentalities'}

# %%
set.union(*df['add codings'].tolist())
# Out:
# {'class membership',
#  'crime',
#  'ecology of group',
#  'employment status',
#  'ethnicity',
#  'family',
#  'gender/sexuality',
#  'health',
#  'income/wealth/economic status',
#  'nationality',
#  'non-econ: other',
#  'occupation/profession',
#  'place/location',
#  'religion',
#  'shared values/mentalities'}

# %% [markdown]
# ##### check if re-coding decisions are internally consistent

# %%
dfs = []
for i, sheet in enumerate(sheets):
    df = pd.read_excel(fp, sheet_name=sheet)

    attribute_cols = df.columns[df.columns.str.contains(':')]
    df[attribute_cols] = df[attribute_cols].replace({np.nan: 'No'})

    df = df.melt(id_vars=['mention_id', 'text', 'mention'], value_vars=attribute_cols, var_name='attribute_combination', value_name='label').sort_values(by=['mention_id', 'attribute_combination']).reset_index(drop=True)

    df['sheet_nr'] = i
    dfs.append(df)

# %%
df = pd.concat(dfs, ignore_index=True).sort_values(['attribute_combination', 'mention_id', ]).reset_index(drop=True)
df.groupby(['mention_id', 'attribute_combination']).filter(lambda x: x.label.nunique() > 1)
# Out:
# Empty DataFrame
# Columns: [mention_id, text, mention, attribute_combination, label, sheet_nr]
# Index: []

# %% [markdown]
# ## Unite

# %% [markdown]
# now
#
# 1. for each sheet parse updated codings from relevant columns containing ":"
# 2. add info about codings to add/discard
# 3. left-join with pre-review codings
# 4. (optionally) tabulate post-review edits

# %%
df = df.sort_values(['mention_id', 'attribute_combination']).reset_index(drop=True)

# %% [markdown]
# #### "1. for each sheet parse updated codings from relevant columns containing ":""

# %%
# NOTE: We can simply use set union because there were no discrepancies/inconsistencies across sheets for any mention
reviewed_codings = df.groupby(['mention_id', 'attribute_combination']).agg({'label': 'first'}).reset_index()

# %% [markdown]
# #### "2. add info about codings to add/discard"

# %%
dfs = []
cols = ['mention_id', 'text', 'mention', 'discard codings', 'add codings']
for i, sheet in enumerate(sheets):
    df = pd.read_excel(fp, sheet_name=sheet)
    idxs = np.logical_or(df['discard codings'].notna(), df['add codings'].notna())
    df = df[idxs]
    df['discard codings'] = df['discard codings'].map(split_and_strip)
    df['add codings'] = df['add codings'].map(split_and_strip)
    df = df[cols]
    df['sheet_nr'] = i+1
    dfs.append(df)

df = pd.concat(dfs, ignore_index=True).sort_values(['mention_id', 'sheet_nr']).reset_index(drop=True)

# %%
edits = df.groupby(['mention_id', 'text', 'mention']).agg({
    'discard codings': lambda x: set.union(*x.tolist()),
    'add codings': lambda x: set.union(*x.tolist())
}).reset_index().sort_values(['mention_id', 'text', 'mention'])

# %%
def make_attribute_combination(x):
    if x is np.NaN:
        return np.NaN
    if x in ['class membership', 'ecology of group', 'education level', 'employment status', 'income/wealth/economic status', 'occupation/profession']:
        return 'economic: '+x
    if x in ['age', 'crime', 'ethnicity', 'family', 'gender/sexuality', 'health', 'nationality', 'place/location', 'religion', 'shared values/mentalities']:
        return 'non-economic: '+x
    return x

cols = ['mention_id', 'text', 'mention']
c = 'discard codings'
to_discard = edits[cols+[c]].explode(c)
to_discard = to_discard[to_discard[c].notnull()]
to_discard['attribute_combination'] = to_discard[c].map(make_attribute_combination)
to_discard['label'] = 'No'
del to_discard[c]

c = 'add codings'
to_add = edits[cols+[c]].explode(c)
to_add = to_add[to_add[c].notnull()]
to_add['attribute_combination'] = to_add[c].map(make_attribute_combination)
to_add['label'] = 'Yes' 
del to_add[c]

tmp = to_discard.merge(to_add, how='outer', on=cols+['attribute_combination'], suffixes=('_discard', '_add'))

# any inconsistencies?
idxs = np.logical_and(~tmp[['label_discard', 'label_add']].any(axis=1), tmp['label_discard']!=tmp['label_add'])
# NOTE: shjould be none !!!
idxs.sum()

to_edit = to_discard.merge(to_add, how='outer', on=cols+['attribute_combination', 'label'])

# %%
to_edit.attribute_combination.value_counts().sort_index()
# Out:
# attribute_combination
# economic: class membership                  5
# economic: ecology of group                  8
# economic: education level                   1
# economic: employment status                13
# economic: income/wealth/economic status     6
# economic: occupation/profession             9
# non-econ: other                             2
# non-economic: age                           1
# non-economic: crime                         2
# non-economic: ethnicity                     3
# non-economic: family                        6
# non-economic: gender/sexuality              5
# non-economic: health                        8
# non-economic: nationality                  10
# non-economic: place/location                3
# non-economic: religion                      2
# non-economic: shared values/mentalities    17
# Name: count, dtype: int64

# %%
to_edit.loc[to_edit['attribute_combination']=='non-econ: other', 'attribute_combination'] = 'non-econ: other'

# %%
to_edit.groupby(['mention_id', 'attribute_combination']).filter(lambda x: x.label.nunique() > 1) # NOTE: should be none !!!
to_edit.groupby(['mention_id', 'attribute_combination']).filter(lambda x: len(x) > 1) # NOTE: should be none !!!
# Out:
# Empty DataFrame
# Columns: [mention_id, text, mention, attribute_combination, label]
# Index: []

# %% [markdown]
# ##### check inconstistencies

# %%
these = reviewed_codings.merge(to_edit[reviewed_codings.columns], how='inner', on=['mention_id', 'attribute_combination'], suffixes=('_reviewed', '_edited')).query('label_reviewed != label_edited').sort_values(['mention_id', 'attribute_combination']).reset_index(drop=True).sort_values('mention_id')
these.merge(df[['mention_id', 'text', 'mention']].drop_duplicates())
# NOTE: in all these instances, `label_edited` is correct, so we can just use it to update the reviewed_codings
# Out:
#                 mention_id                    attribute_combination  \
# 0    13229_201906-194411-1               economic: ecology of group
# 1    14110_201504-201895-1               economic: ecology of group
# 2    14110_201904-203801-1               economic: ecology of group
# 3   171101_200306-303761-1          economic: occupation/profession
# 4   171101_200306-303788-1          economic: occupation/profession
# 5     21112_199111-34952-1               economic: ecology of group
# 6     21112_199505-37048-2  non-economic: shared values/mentalities
# 7    22110_198909-311191-1               economic: ecology of group
# 8    22110_201006-322802-1  economic: income/wealth/economic status
# 9    31110_199303-208306-1  non-economic: shared values/mentalities
# 10   41112_199012-127111-2          economic: occupation/profession
# 11   41320_197211-118594-1                     non-economic: family
# 12   41320_199012-128021-1  non-economic: shared values/mentalities
# 13    43110_198710-98339-1  non-economic: shared values/mentalities
# 14   43901_200710-104046-3              economic: employment status
# 15   51320_198306-223410-1                     non-economic: family
# 16    63110_200410-00030-2  non-economic: shared values/mentalities
# 17    63110_200711-00469-2                  non-economic: ethnicity
# 18   83110_200703-196233-2  non-economic: shared values/mentalities
# 19   86421_200604-261378-1  non-economic: shared values/mentalities
#
#    label_reviewed label_edited  \
# 0             Yes           No
# 1             Yes           No
# 2             Yes           No
# 3              No          Yes
# 4              No          Yes
# 5             Yes           No
# 6              No          Yes
# 7             Yes           No
# 8             Yes           No
# 9              No          Yes
# 10            Yes           No
# 11            Yes           No
# 12             No          Yes
# 13             No          Yes
# 14             No          Yes
# 15            Yes           No
# 16             No          Yes
# 17            Yes           No
# 18             No          Yes
# 19            Yes           No
#
#                                                  text  \
# 0     We want a green society that puts people first.
# 1   Building a zero-emission society means enormou...
# 2   The transition to a zero-emission society must...
# 3   In the matter of environmental pollution, the ...
# 4   However, to the above, the Members of the Gree...
# 5   An industry that must fit into an ecological s...
# 6   Think of the producers of disposable packaging...
# 7   The people who represent this ecological minds...
# 8   From shareholders and managers who merely meas...
# 9   Or go toward an ecological society where the e...
# 10  Their clients are men from all walks of life a...
# 11  Children in homeless settlements and children ...
# 12  Those who want to solve the major transnationa...
# 13  In the face of any ideological differences, pr...
# 14  Companies must hire job-seekers and not interi...
# 15  Our aim will be to introduce a statutory duty ...
# 16  Australians are the world's highest per capita...
# 17  We recognise that, regardless of whether livin...
# 18  The will of the individual to protect the envi...
# 19            Romanian culture is a majority society.
#
#                                               mention
# 0              a green society that puts people first
# 1                             a zero-emission society
# 2                             a zero-emission society
# 3                  the members of the Green Ecologist
# 4                  the Members of the Green Ecologist
# 5                               an ecological society
# 6   the agricultural lobbyists who are fighting ag...
# 7    The people who represent this ecological mindset
# 8   shareholders and managers who merely measure t...
# 9                               an ecological society
# 10         men from all walks of life and professions
# 11                   Children in homeless settlements
# 12  Those who want to solve the major transnationa...
# 13                               all the green forces
# 14                          interim or border workers
# 15                            all pre-school children
# 16      the world's highest per capita users of water
# 17        the most disadvantaged group in our society
# 18                              a sustainable society
# 19                                 a majority society

# %%
reviewed_codings = reviewed_codings.merge(to_edit[reviewed_codings.columns], how='outer', on=['mention_id', 'attribute_combination'], suffixes=('', '_edited')).sort_values(['mention_id', 'attribute_combination'])

idxs = reviewed_codings['label'].isnull()
reviewed_codings.loc[idxs, 'label'] = reviewed_codings.loc[idxs, 'label_edited']

idxs = np.logical_and(reviewed_codings['label_edited'].notnull(), reviewed_codings['label_edited']!=reviewed_codings['label'])
reviewed_codings.loc[idxs, 'label'] = reviewed_codings.loc[idxs, 'label_edited']

del reviewed_codings['label_edited']

# %%
reviewed_codings.groupby(['mention_id', 'attribute_combination']).filter(lambda x: x.label.nunique() > 1) # NOTE: should be none !!!
reviewed_codings.groupby(['mention_id', 'attribute_combination']).filter(lambda x: len(x) > 1) # NOTE: should be none !!!
# Out:
# Empty DataFrame
# Columns: [mention_id, attribute_combination, label]
# Index: []

# %% [markdown]
# #### "3. left-join with pre-review codings"

# %%
tmp = pre_review.query("attribute_combination not in @ignore").merge(reviewed_codings, how='left', on=['mention_id', 'attribute_combination'], suffixes=('', '_reviewed')).sort_values(['mention_id', 'attribute_combination']).reset_index(drop=True)
cols = ['mention_id', 'text', 'mention']
tmp = annotations[cols].drop_duplicates().reset_index(drop=True).merge(tmp)

# %%
tmp.groupby(['mention_id', 'attribute_combination']).filter(lambda x: x.label.nunique() > 1) # NOTE: should be none !!!
tmp.groupby(['mention_id', 'attribute_combination']).filter(lambda x: len(x) > 1) # NOTE: should be none !!!
# Out:
# Empty DataFrame
# Columns: [mention_id, text, mention, attribute_combination, label, label_reviewed]
# Index: []

# %%
idxs = np.logical_and(tmp['label_reviewed'].notnull(), tmp['label']!=tmp['label_reviewed'])
idxs.mean() # % share of judgments corrected in expert review
# Out:
# 0.011481481481481481

# %%
for mid, m in tmp[idxs].groupby('mention_id'):
    text = m.text.iloc[0]
    mention = m.mention.iloc[0]
    print(f'{mid}: "' + text.replace(mention, '\u001B[30m\u001B[43m'+mention+'\033[0m') + '"')
    for i, row in m.iterrows():
        print(f"  - \033[1m{row['attribute_combination']}\033[0m:  {row['label']} -> {row['label_reviewed']}")
    print()
# Out:
# 11110_200209-393006-1: "Students with children have great difficulties bringing the economy together."
#   - non-economic: age:  Yes -> No
#
# 11320_200609-394026-2: "Elderly care and care should be of high quality.3 500 experienced elderly care employees will be offered to become mentors."
#   - non-economic: health:  Yes -> No
#
# 11320_201409-397483-1: "Everyone working in the elderly care sector should be trained in dementia and multi-disease."
#   - non-economic: health:  Yes -> No
#
# 12951_199309-331714-1: "Unemployed persons who do not want to work will lose their insurance."
#   - non-economic: shared values/mentalities:  No -> Yes
#
# 13229_199409-186604-1: "You can be sure to find us on the same page as the movements that work for better social conditions for the Copenhagen people."
#   - non-economic: nationality:  Yes -> No
#   - non-economic: place/location:  No -> Yes
#
# 13229_199409-186607-1: "Dreams of a good life for all Copenhageners can only be secured through activity, pressure and struggle from trade unions, parental organizations, environmental organizations and others, whether one wishes to stop destructive, prestige buildings, to remove the waiting list for nurseries, or to expand home care for the elderly."
#   - non-economic: nationality:  Yes -> No
#   - non-economic: place/location:  No -> Yes
#
# 13229_201906-194411-1: "We want a green society that puts people first."
#   - economic: ecology of group:  Yes -> No
#
# 13230_198112-182709-1: "Those who are now referred to living from public income transfers must have improved their income."
#   - economic: income/wealth/economic status:  No -> Yes
#
# 13230_199409-186738-1: "Whether unemployment affects one person or people from one’s family or surroundings."
#   - economic: employment status:  Yes -> No
#
# 13720_201506-194129-1: "Including the elderly, who have built up the Danish society and have difficulty coping with themselves."
#   - non-economic: shared values/mentalities:  No -> Yes
#
# 13951_197501-181621-1: "This is in the interests of both workers and employers."
#   - economic: employment status:  Yes -> No
#
# 14110_201104-200153-1: "The holiday banking system also enables annual holidays for workers in the field of grinding and grinding work that fluctuate between several employers."
#   - economic: class membership:  Yes -> No
#   - economic: employment status:  Yes -> No
#
# 14110_201504-201895-1: "Building a zero-emission society means enormous amounts of new industrial production, jobs and export opportunities."
#   - economic: ecology of group:  Yes -> No
#
# 14110_201904-203800-2: "Involve all stakeholders in society: workers, industry, civil society."
#   - economic: class membership:  Yes -> No
#   - economic: employment status:  Yes -> No
#   - economic: occupation/profession:  No -> Yes
#
# 14110_201904-203801-1: "The transition to a zero-emission society must be done safely and fairly."
#   - economic: ecology of group:  Yes -> No
#
# 14110_201904-203808-1: "Make a plan to support different sectors and groups of people in their transition from the fossil economy."
#   - economic: occupation/profession:  No -> Yes
#
# 14820_197903-197512-1: "Do not submit to the betrayers of your promises."
#   - economic: occupation/profession:  Yes -> No
#
# 14820_198703-197638-1: "Residents of the forests must be brought to decent housing for those still homeless in 1987."
#   - economic: income/wealth/economic status:  Yes -> No
#
# 14820_199103-197922-1: "The world needs free entrepreneurs."
#   - economic: employment status:  Yes -> No
#   - economic: occupation/profession:  No -> Yes
#
# 15111_199905-280303-1: "The leftist movement - green supply wants to apply for the development of the 4 / 1 workforce towards increased diversity and benefit from environmentally-friendly technologies."
#   - economic: ecology of group:  Yes -> No
#   - economic: occupation/profession:  Yes -> No
#
# 15111_201710-281205-1: "Insurance needs access to a diversified culture in a multicultural society."
#   - non-economic: shared values/mentalities:  Yes -> No
#
# 171101_200306-303761-1: "In the matter of environmental pollution, the members of the Green Ecologist Party of Mexico will seek to ensure compliance with the Official Mexican Standards and current legislation on prevention, as well as to ensure that the maximum permissible levels of emissions to the atmosphere as well as discharges of wastewater in basins are reduced."
#   - economic: occupation/profession:  No -> Yes
#
# 171101_200306-303788-1: "However, to the above, the Members of the Green Ecologist Party of Mexico consider it necessary:"
#   - economic: occupation/profession:  No -> Yes
#
# 21111_198111-22981-1: "representatives of women’s associations."
#   - non-economic: gender/sexuality:  Yes -> No
#
# 21111_198111-23163-2: "A reduction in employer contributions is planned for certain categories of workers, but for workers organized into production cooperatives, workers in SMEs located in the crafts and repair sectors and workers employed by agricultural cooperatives."
#   - economic: class membership:  Yes -> No
#   - economic: employment status:  Yes -> No
#
# 21111_199111-32560-1: "Immigration: A multicultural society."
#   - non-economic: shared values/mentalities:  Yes -> No
#
# 21112_199111-34952-1: "An industry that must fit into an ecological society must therefore look completely different."
#   - economic: ecology of group:  Yes -> No
#
# 21112_199505-37048-2: "Think of the producers of disposable packaging that oppose eco-taxes or the agricultural lobbyists who are fighting against a solution to the fertilizer problem."
#   - economic: occupation/profession:  No -> Yes
#   - non-economic: shared values/mentalities:  No -> Yes
#
# 21914_199111-35733-2: "The problem of foreigners in Flanders is primarily caused by the host workers."
#   - economic: class membership:  Yes -> No
#   - economic: employment status:  Yes -> No
#
# 21914_199906-50888-1: "Many of the exotic self-employed are also a market disturbing element."
#   - non-economic: nationality:  Yes -> No
#
# 22110_198909-311191-1: "The people who represent this ecological mindset can be found in the environmental movement, among technological innovators, in organizations and political parties."
#   - economic: ecology of group:  Yes -> No
#
# 22110_198909-311332-2: "Particular attention is required to the position of the start-up female and ethnic entrepreneurs."
#   - economic: employment status:  Yes -> No
#
# 22110_200301-320182-1: "Not just from anonymous cameras, but from the people who live and work there."
#   - economic: occupation/profession:  Yes -> No
#   - non-economic: place/location:  No -> Yes
#
# 22110_201006-322802-1: "From shareholders and managers who merely measure the performance of companies to the short-term profit."
#   - economic: income/wealth/economic status:  Yes -> No
#   - non-economic: shared values/mentalities:  No -> Yes
#
# 22110_201209-324919-1: "Farmers who choose sustainable and animal-friendly production also need to get plenty of jobs."
#   - non-economic: shared values/mentalities:  No -> Yes
#
# 22711_199405-314713-1: "The subsidy and preferential scheme for ethnic entrepreneurs is abolished."
#   - economic: employment status:  Yes -> No
#
# 23113_199406-295593-1: "The more smoothly domination works, the less it is conscious of the dominated."
#   - non-economic: gender/sexuality:  Yes -> No
#
# 23113_200906-299460-2: "to promote the integration of persons with disabilities into the ordinary labour market and to develop action programmes aimed at creating more jobs for such persons in the public sector;"
#   - non-economic: health:  Yes -> No
#
# 31110_199303-208306-1: "Or go toward an ecological society where the economic no longer dominates social relations and no longer destroys nature?"
#   - non-economic: shared values/mentalities:  No -> Yes
#
# 31110_201206-217612-1: "Careers of cultural workers and French foreign language teachers."
#   - economic: class membership:  Yes -> No
#   - economic: employment status:  Yes -> No
#
# 31720_200706-212385-1: "It unites freedom and security within the national framework which, recent experience as the teachings of history prove, is as indispensable to life as the boarding of a boat: the fence against threatening waves and the shell that contains the hopes of passengers."
#   - non-economic: nationality:  Yes -> No
#
# 31720_201206-218058-1: "The lower rates will favor individual entrepreneurs and SMEs."
#   - economic: employment status:  Yes -> No
#   - economic: occupation/profession:  No -> Yes
#
# 32630_201302-287800-2: "One part comes from the evasion of SMEs and another residual from self-employed workers."
#   - economic: class membership:  Yes -> No
#   - economic: occupation/profession:  No -> Yes
#
# 41111_198701-123538-9: "The Federal Republic must acknowledge its responsibility to the victims of fascism and recognize the compensation demands of all the victims of the Nazi, especially the Roma and Sinti, the Jewish people, the homosexuals, the forced sterilized, the survivors of the "ethanasia" actions, the resistance fighters and the so-called associalists."
#   - non-economic: crime:  No -> Yes
#
# 41112_199012-126399-1: "Only a peaceful, non-violent society is a decent society."
#   - non-economic: crime:  Yes -> No
#
# 41112_199012-127111-2: "Their clients are men from all walks of life and professions."
#   - economic: occupation/profession:  Yes -> No
#
# 41320_197211-118594-1: "Children in homeless settlements and children from other marginalized groups."
#   - non-economic: family:  Yes -> No
#
# 41320_197610-119535-2: "This is what today’s pensioners and the working generation can expect in the future."
#   - economic: employment status:  No -> Yes
#
# 41320_199012-127606-1: "This also includes more participation for workers and their trade unions in the enterprise."
#   - economic: class membership:  Yes -> No
#   - economic: employment status:  Yes -> No
#   - economic: occupation/profession:  No -> Yes
#
# 41320_199012-128021-1: "Those who want to solve the major transnational challenges, such as environmental protection, need a strong Europe."
#   - non-economic: shared values/mentalities:  No -> Yes
#
# 41521_200209-139610-1: "We will take advantage of the opportunities of co-determination through a better and more modern corporate constitutional law, remove the recruitment barriers created by the Schröder government and preserve the diversity of workers' interests."
#   - economic: class membership:  Yes -> No
#   - economic: employment status:  Yes -> No
#   - economic: occupation/profession:  No -> Yes
#
# 41521_201309-160624-1: "This is precisely why we need existential founders who want to realize their ideas and create jobs and prosperity in this way."
#   - economic: employment status:  Yes -> No
#
# 41953_201709-170554-1: "Most of the perpetrators of organized crime are foreigners."
#   - non-economic: nationality:  Yes -> No
#
# 42110_198611-03946-1: "Powerful cliques behind and within the old parties are heading towards the Great Coalition."
#   - economic: class membership:  No -> Yes
#   - economic: occupation/profession:  Yes -> No
#
# 42420_199410-07812-1: "A very successful entrepreneur."
#   - economic: employment status:  Yes -> No
#   - economic: occupation/profession:  No -> Yes
#
# 42420_199512-08848-1: "The environmental impact of intensive agriculture should be reduced through direct payments to farmers."
#   - economic: ecology of group:  Yes -> No
#
# 42420_200211-11355-1: "Without such a restriction on the free movement of workers, Austria would have been affected by a massive immigration and professional donation migration due to the strong wage differences and, consequently, by a significant increase in the shortage of Pushcher, which would have led to a competition for displacement, i.e. a massive increase in the unemployment of domestic workers."
#   - economic: class membership:  Yes -> No
#   - economic: employment status:  Yes -> No
#   - economic: occupation/profession:  No -> Yes
#
# 42420_200211-11355-2: "Without such a restriction on the free movement of workers, Austria would have been affected by a massive immigration and professional donation migration due to the strong wage differences and, consequently, by a significant increase in the shortage of Pushcher, which would have led to a competition for displacement, i.e. a massive increase in the unemployment of domestic workers."
#   - economic: class membership:  Yes -> No
#   - economic: employment status:  Yes -> No
#
# 42710_200809-14967-1: "The BZÖ wants to expand the child allowance introduced by it to a maternity salary of 1,000 euros for all those mothers who want to dedicate themselves entirely to the upbringing of their children."
#   - economic: employment status:  Yes -> No
#   - non-economic: gender/sexuality:  No -> Yes
#
# 43110_198710-98339-1: "In the face of any ideological differences, promoting the cooperation of all the green forces is our primary concern."
#   - non-economic: shared values/mentalities:  No -> Yes
#
# 43110_201110-104517-3: "Children with a migrant background, children from an educational background or children with a dependent or mentally ill parent often have poor opportunities when entering school."
#   - economic: income/wealth/economic status:  Yes -> No
#
# 43901_200710-104046-3: "Companies must hire job-seekers and not interim or border workers."
#   - economic: class membership:  Yes -> No
#   - economic: occupation/profession:  No -> Yes
#
# 51320_198306-223410-1: "Our aim will be to introduce a statutory duty on local authorities to provide nursery education, as soon as possible, for all pre-school children whose parents wish it."
#   - non-economic: family:  Yes -> No
#
# 51320_201912-249581-1: "Labour will end the scandal of leasehold for the millions who have bought their home but don't feel like they own it."
#   - non-economic: shared values/mentalities:  No -> Yes
#
# 51620_200505-235163-1: "Parents who work hard to give their children the best start in life need a government that is on their side."
#   - economic: employment status:  Yes -> No
#
# 51620_200505-235251-2: "We will give patients and local GPs the right to choose the hospital or care provider that is right for them."
#   - non-economic: health:  Yes -> No
#
# 51620_200505-235254-2: "Small community hospitals which have the support of local patients and GPs will not be closed by bureaucrats."
#   - non-economic: health:  Yes -> No
#
# 51620_201505-241457-4: "Patients, doctors and nurses are the experts on how to improve people's health."
#   - non-economic: health:  Yes -> No
#
# 51620_201706-245039-1: "Rather than pursue an agenda based on a supposed centre ground defined and established by elites in Westminster, we will govern in the interests of the mainstream of the British public."
#   - economic: income/wealth/economic status:  Yes -> No
#
# 53110_199211-276429-1: "Only in a society in which 'feminine' values are given their full role will it be possible for ecological values to exist."
#   - non-economic: gender/sexuality:  No -> Yes
#
# 53110_199211-276467-1: "The State should provide credit and training to landless people who wish to enter agriculture."
#   - economic: income/wealth/economic status:  No -> Yes
#   - economic: occupation/profession:  Yes -> No
#   - non-economic: shared values/mentalities:  No -> Yes
#
# 61320_200411-423713-2: "The dream of the middle class should belong to all Americans willing to work for it."
#   - economic: employment status:  Yes -> No
#
# 61320_201611-430948-6: "from nurses, firefighters, and teachers to construction workers, factory workers, and small business owners."
#   - economic: employment status:  Yes -> No
#   - economic: occupation/profession:  No -> Yes
#
# 61620_198411-412422-1: "Republicans put the needs of people at the center of environmental concerns."
#   - economic: ecology of group:  No -> Yes
#
# 63110_200410-00030-2: "Australians are the world's highest per capita users of water."
#   - non-economic: shared values/mentalities:  No -> Yes
#
# 63110_200711-00469-2: "We recognise that, regardless of whether living in urban or remote communities, they are the most disadvantaged group in our society."
#   - economic: income/wealth/economic status:  No -> Yes
#   - non-economic: ethnicity:  Yes -> No
#
# 80640_201703-95265-3: "Creation of a specialized team that initiates and implements projects related to the artistic and creative industries, and the artistic and creative skills of young people who want to realize themselves in another sphere, regardless of their choice of profession; Creation of a center for talented children (in particular - with dyslexia), and specialized educational and extra-class programs/ parallels for them; Creation of the "Ministry of Innovations" which drafts strategy and tactics based on future world trends (10+ years), and which starts from now on the preparation of processes, people, skills, experimental developments, pilot projects through which will ensure the long-term survival of Bulgaria (e.g. are people prepared for the moment when cars will be inexperienced and there will be no need for drivers, or what people will work, whose professions will be and can be"
#   - economic: education level:  Yes -> No
#   - non-economic: family:  Yes -> No
#
# 80710_200907-92925-2: "Complete revision of the return of land to their true owners or their heirs."
#   - economic: income/wealth/economic status:  Yes -> No
#   - non-economic: family:  No -> Yes
#
# 83110_200703-196233-2: "The will of the individual to protect the environment and to build a sustainable society is not enough."
#   - non-economic: shared values/mentalities:  No -> Yes
#
# 86421_200604-261378-1: "Romanian culture is a majority society."
#   - non-economic: shared values/mentalities:  Yes -> No
#
# 86421_201404-269849-1: "Those who stand on their heels and wear gloves even in the most difficult situations."
#   - economic: occupation/profession:  No -> Yes
#
# 86710_201404-270610-2: "Together, these companies have deceived the majority of those involved in the currency lending trap."
#   - economic: income/wealth/economic status:  Yes -> No
#
# 86710_201804-274934-1: "The same is needed for young people who are unable or unwilling to integrate into the normal educational system because of their behavioral problems."
#   - non-economic: health:  No -> Yes
#
# 92436_200109-360301-1: "People who started with goods carried across the border in suitcases and from field beds on the streets, from small consulting firms and service workshops, gradually built shops, wholesalers, factories, corporations and today give jobs to dozens of people: workers."
#   - non-economic: nationality:  No -> Yes
#
# 92436_200509-360693-2: "It is necessary to expand the lustration, to disclose all peer-related special services officers and secret collaborators."
#   - economic: employment status:  Yes -> No
#   - economic: occupation/profession:  No -> Yes
#
# 92712_199110-359840-1: "A professional group that sees the enormous insecurity of the nation."
#   - non-economic: shared values/mentalities:  No -> Yes
#
# 93712_199209-377150-1: "Between different social and professional categories, between generations, hostile theses with territorial claims are being brought to the surface, and step by step, through a whole arsenal of means, the dismemberment of Romania is sought."
#   - economic: occupation/profession:  No -> Yes
#
# 96710_199206-378041-2: "maintaining the spa industry in the ownership of domestic entrepreneurs and companies."
#   - economic: employment status:  Yes -> No
#   - economic: occupation/profession:  No -> Yes
#
# 96710_199809-378834-1: "A nation is an ethnic community, a homogeneous ethnic space in which one can only be born."
#   - non-economic: ethnicity:  No -> Yes
#
# 96710_201006-381008-1: "The upbringing and education of our children and youth is the most responsible and noble task of society."
#   - non-economic: family:  Yes -> No

# %%
tmp.loc[idxs, 'label'] = tmp.loc[idxs, 'label_reviewed']
del tmp['label_reviewed']

# %%
cols = annotations.columns.tolist()
cols.remove('label')

tmp = annotations[cols].merge(tmp, on=tmp.columns[:-1].tolist(), how='outer')
tmp.loc[idxs, 'round'] = 4

# %%
tmp.groupby(['mention_id', 'attribute_combination']).filter(lambda x: x.label.nunique() > 1) # NOTE: should be none !!!
tmp.groupby(['mention_id', 'attribute_combination']).filter(lambda x: len(x) > 1) # NOTE: should be none !!!
# Out:
# Empty DataFrame
# Columns: [mention_id, text, mention, prev_texts, next_texts, q_id, q_category, category, round, attribute, attribute_combination, label]
# Index: []

# %%
fp = data_path / 'consolidated_annotations_post_review.tsv'
tmp.to_csv(fp, sep='\t', index=False)
