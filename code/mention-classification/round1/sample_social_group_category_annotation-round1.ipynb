# %%
from types import SimpleNamespace

args = SimpleNamespace()

args.group_type = 'social group'

# %%
import os

import pandas as pd

from utils.io import read_jsonlines
from utils.parsing import unnest_sequence_annotations
from utils.embedding import E5SentenceEmbedder
from reconstruction_loss_ranker import ReconstructionLossRanker
from utils.qualtrix import make_mention_categorization_block

# %%
base_path = os.path.join('..', '..')
data_path = os.path.join(base_path, 'data')
SEED = 42

# %% [markdown]
# ### Read the mention annotations

# %%
annotations_path = os.path.join(data_path, 'annotations', 'group_mention_detection')
jobs = [nm for nm in os.listdir(annotations_path) if nm.startswith('group-mention-annotation-batch-')]
fps = [os.path.join(data_path, job, 'review_annotations.jsonl') for job in jobs]

parse_entry = lambda x: {k: x[k] for k in ['id', 'text', 'label']}
data = [parse_entry(line) for fp in fps for line in read_jsonlines(fp)]

df = pd.DataFrame(unnest_sequence_annotations(data, keep_text=True))

# %% [markdown]
# ### Read the mention metadata

# %%
fp = os.path.join(data_path, 'manifestos', 'all_manifesto_sentences_translated.tsv')
sentence_df = pd.read_csv(fp, sep='\t')

sentence_df.rename(columns={'sentence_id': 'text_id', 'text_mt_m2m_100_1.2b': 'text_en'}, inplace=True)
sentence_df['manifesto_id'] = sentence_df.text_id.str.split('-', expand=True)[0]

# for each line, within manifesto, get the two texts occuring before and after the line in separate columns 
sentence_df['prev_texts'] = sentence_df.groupby('manifesto_id')['text_en'].shift([2, 1], fill_value='').values.tolist()
sentence_df['prev_texts'] = sentence_df['prev_texts'].apply(lambda x: [t for t in x if t != ''])
sentence_df['next_texts'] = sentence_df.groupby('manifesto_id')['text_en'].shift([-1, -2], fill_value='').values.tolist()
sentence_df['next_texts'] = sentence_df['next_texts'].apply(lambda x: [t for t in x if t != ''])

# %%
# merge with annotations
df = pd.merge(df, sentence_df[['text_id', 'prev_texts', 'next_texts']], on='text_id', how='left')

# %%
# subset to relevant group category
examples = df[df.type == args.group_type].reset_index(drop=True)

# %% [markdown]
# ### Embed the mentions

# %%
embedder = E5SentenceEmbedder(device='mps')

# %%
# we leverage the fact that the E5 embedding model is designed for retrieving relevant answers to a query
#  asking what kind of group a mention refers to shoudl encode its meaning
prompt_template = "Query: In the context of the sentence '''{text}''', what kind of group does '''{mention}''' refer to?"
prompts = examples.apply(lambda r: prompt_template.format(text=r['text'], mention=r['mention']), axis=1).to_list()

# %%
embeddings = embedder.encode(prompts, batch_size=32)
# Out:
#   0%|          | 0/145 [00:00<?, ?it/s]

# %%
from typing import Literal
from transformers import set_seed
from utils import clean_memory

def rank(
        embeddings,
        epochs: int=25_000,
        seed: int=42,
        device: Literal['cuda', 'mps', 'cpu']='cpu', 
        verbose: bool=False,
    ):
    set_seed(seed)
    ranker = ReconstructionLossRanker(hdim=embeddings.shape[0], num_epochs=epochs, log_n_steps=2_500, device=device, seed=seed)
    idxs, _ = ranker.fit(data=embeddings, verbose=verbose)
    
    ranker.cpu();
    del ranker
    clean_memory(device=device)

    return idxs

# %%
idxs = rank(embeddings, epochs=20_000, verbose=True)
# Out:
# [2024-09-12 20:21:32] epoch [1/20000], loss: 47.1449
# [2024-09-12 20:25:41] epoch [2501/20000], loss: 40.4800
# [2024-09-12 20:29:48] epoch [5001/20000], loss: 34.6800
# [2024-09-12 20:33:56] epoch [7501/20000], loss: 28.8878
# [2024-09-12 20:38:23] epoch [10001/20000], loss: 23.1037
# [2024-09-12 20:42:30] epoch [12501/20000], loss: 17.3286
# [2024-09-12 20:46:32] epoch [15001/20000], loss: 11.5663
# [2024-09-12 20:48:37] Final loss after 16300 epochs: 0.0116

# %%
examples.iloc[idxs, [5, 6]].head(50)
# Out:
#                                                 mention  \
# 2883                     The workforce in the companies
# 2777                        women from poorer countries
# 3027                            those who are not taxed
# 1360                                           citizens
# 1230  a minority group of the population of this cou...
# 1976                         people with mental illness
# 1894                                       the Italians
# 2649                                         any worker
# 3739                                      nursing staff
# 1617                                       the students
# 4246                                         households
# 3176  Single parents, of whom the absolute majority ...
# 2734                                   school graduates
# 3078                                          consumers
# 1878                                      the individua
# 3652                        those working in the sector
# 1302              children in their first years of life
# 2768                                                man
# 1580                                       the citizens
# 909                                      the population
# 30    people who are not specialized in industry-lea...
# 2908                                           everyone
# 341                                         the elderly
# 2484                                        generations
# 1342                              almost all applicants
# 4372                                    our communities
# 2361                                         The family
# 1733                     the concrete people and groups
# 1841  A society in which everyone can believe what t...
# 4191                                    American adults
# 805                                              people
# 2303                                         the public
# 2769                        the families that need them
# 2913                                 illegal immigrants
# 4133                                         The family
# 218                                the Flemish majority
# 2020                                             Others
# 2613  few people in the business world and in the po...
# 3637  those who are alarmed at the growth of violenc...
# 305                                               women
# 3821  the employers who actually hold the power, inc...
# 2478                          The family of generations
# 4056                      large-scale private investors
# 2024                 workers with precarious labor ties
# 2749                                      Our community
# 1879                               Our Cypriot brothers
# 3757                                       Young people
# 3007                                     the unemployed
# 3287                                 a majority society
# 836                                   the Danish people
#
#                                                    text
# 2883   The workforce in the companies is getting older.
# 2777  The extreme expression of this is when women f...
# 3027                      Even those who are not taxed.
# 1360  There is a clear link between the freedom of c...
# 1230  The law, which will respect current migration ...
# 1976  This is especially true of people with mental ...
# 1894  First the Italians in access to social service...
# 2649  the revision of the status of temporary worker...
# 3739  A Netherlands to be proud again!16 billion tax...
# 1617  The individual higher education institution is...
# 4246  The disintegration of the economic process of ...
# 3176  Single parents, of whom the absolute majority ...
# 2734  The first decade of the next century will reac...
# 3078  Create a label that highlights French artisana...
# 1878  The system of market economy is above all a co...
# 3652  Increasing the salary of those working in the ...
# 1302  In order to accompany children in their first ...
# 2768  But this war that man fights against nature al...
# 1580  Possible municipal associations must be made o...
# 909   Irish people with disability represent a signi...
# 30    The service industries can better employ peopl...
# 2908  We expect our rule of law to give us internal ...
# 341   This is especially important for the elderly a...
# 2484  Between different social and professional cate...
# 1342  Thus, it was possible that almost all applican...
# 4372  Private entities which facilitate adoptions en...
# 2361             The family is the core of our society.
# 1733  Basic democracy assumes that every decision sh...
# 1841  A society in which everyone can believe what t...
# 4191  One in four American adults live with a disabi...
# 805   We want to make it profitable to produce their...
# 2303                         Properly inform the public
# 2769  First, we want to see that enough homes are pr...
# 2913  Greece is a country with borders, external and...
# 4133                 The family is the germ of society.
# 218   The Belgian state, built on the patience and i...
# 2020  Others go for months and wait for a knee surgery.
# 2613  Far from the public light, few people in the b...
# 3637  We share the view of those who are alarmed at ...
# 305                     Equality between men and women.
# 3821  We will take action to guarantee that when wor...
# 2478                         The family of generations.
# 4056  Banks, hedge funds and large-scale private inv...
# 2024  Social Security system for workers with precar...
# 2749  Our community lives on spiritual foundations t...
# 1879  Our Cypriot brothers are called to talk under ...
# 3757  Young people are delaying the founding of fami...
# 3007  In addition to the fact that there are suffici...
# 3287            Romanian culture is a majority society.
# 836                             Only the Danish people.

# %%
# return
examples['informativeness_rank'] = idxs+1
examples.sort_values('informativeness_rank', inplace=True)
examples.reset_index(drop=True, inplace=True)

# %%
examples.prev_texts = examples.prev_texts.apply(lambda s: '\n'.join(s))
examples.next_texts = examples.next_texts.apply(lambda s: '\n'.join(s))

# %%
group_type = args.group_type.replace(' ', '_')
fp = os.path.join(data_path, 'intermediate', f'{group_type}_mentions_ranked.tsv')
examples.to_csv(fp, sep='\t', index=False)
